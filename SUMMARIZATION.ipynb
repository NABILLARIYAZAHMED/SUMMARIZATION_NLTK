# %%
from urllib.request import urlopen
#urlopen is used to open a remote object across a network and read it.
#urllib contains func for requesting data across web
from bs4 import BeautifulSoup
#bs is used for pulling data from html/xml files
url="https://en.wikipedia.org/wiki/Malayalam"
html=urlopen(url).read()#read source code
soup=BeautifulSoup(html)
#Now you have to pass something to BeautifulSoup to create a soup object.
#That could be a document or an URL.(obj creation)
for script in soup(["script","style"]):#remove all tags
    script.extract()#contains text but it is obj so store it
text=soup.get_text()#text format
lines="\n".join(line.strip() for line in text.splitlines())#lines/space remove
# Out:
# C:\Users\HP\Anaconda\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\HP\Anaconda\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
from gensim.summarization import keywords

print ('Keywords:')
print (keywords(text))
len(keywords(text))
# Out:
# Keywords:
# malayalam
# language
# languages
# kerala
# dialects
# dialect
# dialectical
# edit
# edition
# edited
# tamil
# tamils
# sanskrit
# sanskritic
# words
# word
# script
# scripts
# new
# news
# retrieved
# retrieval
# india
# literature
# vowels
# vowel
# literary work
# works
# dravidian
# dravidians
# form
# forms
# forming
# formed
# differences
# different
# difference
# kannada
# malabar
# personal
# manipravalam
# called
# south
# poet
# poets
# english
# central
# style
# styles
# features
# feature
# indian
# written
# like
# malayali
# malayalis
# article
# articles
# official
# officially
# common
# commons
# prose
# meaning
# means
# tulu
# speakers
# speaker
# pillai
# century
# centuries
# person singular
# link
# links
# kurumba
# isbn
# historical
# historically
# consonants
# consonant
# vocative
# vocatives
# voc
# element
# differing considerably
# krishna
# number
# numbers
# songs
# song
# history
# nairs
# nair
# indo
# social
# references
# refer
# referring
# reference
# phonological elements
# nouns
# noun
# portuguese
# source
# sources
# view
# viewed
# views
# community
# communal
# examples
# example
# western
# stems
# phonology
# case
# cases
# state
# states
# alphabet
# alphabets
# period
# kollam
# letters
# letter
# names
# named
# region
# regional
# regions
# dated
# dates
# poem
# poems
# alveolar
# linguistics
# linguistic
# poetry
# educated
# education
# character
# characters
# emotional
# book
# books
# menon
# christians
# christian
# wikipedia
# originally referred
# nominative
# retroflex
# north
# drama
# dramas
# stem ending
# main
# early
# school
# schools
# patterns
# pattern
# author
# authors
# authority
# local
# press
# presses
# writing
# write
# writes
# writings
# grantha
# citations
# travancore
# bengali novels
# syriac
# proto
# native
# pdf
# university
# universities
# started
# start
# geographic
# geographical
# grammar
# date mark
# attakkatha
# high
# known
# movements
# movement
# pattu
# gave
# educational activities
# classical
# old
# later
# lateral
# laterals
# government
# marangale
# marangalal
# total
# developed
# development
# developers
# international
# varma
# lakshadweep
# districts
# district
# ezhuthachan
# needed
# needing
# telugu
# sociative
# church
# churches
# given
# end
# ends
# endings
# mission
# depicts
# depicting
# page
# time
# times
# translates
# translated
# translation
# translating
# translators
# translations
# category
# categories
# arabic
# dative
# medieval
# origin
# originated
# original
# major
# symbols
# symbol
# symbolic
# urdu
# according
# iso
# khasi
# thiruvananthapuram
# kottayam
# earliest
# wikimedia
# area
# areas
# external influences
# brahmi
# hindi
# nilgiris
# nilgiri
# mala
# wayanad
# island
# addition
# additional
# avar
# avare
# avaral
# printed
# printing
# print
# accusative
# kodava
# text
# texts
# relations
# relation
# related
# generally
# generous
# general
# generation
# spoken
# instrumental
# kadars
# kadar
# latin
# tourism
# archived
# archives
# pub
# malay
# malai
# sora
# novel
# hindu
# census
# july
# islands including
# nasrani
# nasranis
# activism
# caves
# cave
# genitive
# follows
# followed
# following
# non
# marked
# marks
# panikkar
# containing
# contains
# contained
# influence
# influenced
# variations
# variation
# krsna
# great
# portal
# pattikale
# pattikalal
# political
# politics
# european
# occurs
# occur
# occurring
# territory
# territories
# use
# uses
# blending
# thampuran
# pua
# intalkcontributionscreate
# nynorskoʻzbekcha
# arthashastra
# completely
# completed
# visitor
# brilliant
# near
# derived
# textbooks
# ninnute
# avalute
# irayimman
# tongue
# types
# type
# typing
# mention
# mentioned
# mentioning
# gondi
# ramayana
# include
# kathakali
# standard
# standards
# standardizing
# april
# unsourced
# agencies
# london
# codes
# code
# kolkali
# masculine
# rajya
# germany
# mizo
# nation
# national
# palakkad
# sahitya
# koya
# considerable
# shows
# showing
# tree
# toda
# message
# surnames
# sikkimese
# robert
# kodagu
# flower
# certain
# recently
# recent
# abound
# abounding
# cochin
# locative
# manusyan
# manusyane
# manusyanal
# actual
# actually
# magahi
# projects
# anakale
# objective
# permanent
# permanently
# indicates
# indicated
# indic
# indicate
# britannica
# titles
# title
# mundari
# konkani
# singapore
# reserved
# reserve
# table
# okkekkum ariyendunna
# banjamin
# bailey
# stats
# protection
# protected
# short
# coast
# manusyar
# manusyare
# manusyaral
# story
# stories
# https
# http
# bhojpuri
# ethnologue
# learn
# learned
# learning
# ezhavas
# ezhava
# usually
# muthuvans
# muthuvan
# kumaoni
# legislative
# public
# british
# lake
# navigation
# encyclopedia
# irula
# rasa
# rasas
# second
# wayback
# kurukh
# way
# ways
# mappila
# mappilas
# malayanma
# wrote
# vyakaranam
# pazhancholmala
# ninnalil
# phonetics
# phonetic
# phonetically
# expressions
# expression
# express
# paper
# chera
# came
# koraga
# ramanujan
# county
# romanization
# roman
# xxiv
# topic
# topics
# thoma
# thomas
# levels
# level
# nannalil nammil
# geography
# nannal
# nannale
# nannalal
# kolami
# simiрусскииससकतमscotssimple
# српскохрватскиsuomisvenskatagalogதம
# malayalabhaasha
# swaroopam
# lie
# talents
# talented
# human
# recognition
# population
# asan
# nammal
# santali
# travel
# govindaraju
# banjarban
# angika
# policy
# hill
# hills
# kuvi
# unaspirated
# unclassified
# plosive
# plosives
# gulf
# garo
# family
# ninnalotu
# resembles
# resembling
# resemblance
# venad
# rajasthani
# special
# speaking
# allar
# iyer
# iyers
# srpskisrpskohrvatski
# englishslovencinaslovenscinaslunskiсрпски
# maram
# marame
# template
# 4645

# %%
from gensim.summarization import summarize
# Out:
# C:\Users\HP\Anaconda\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
print (len(summarize(lines, ratio=0.1)))#ratio use for part of lines,large amt of data is seen (so i found noof lines)
# Out:
# 25109

# %%
len(lines)#actual length
# Out:
# 68078

# %%
print (summarize(lines, word_count=50))
# Out:
# Robert Caldwell, in his book "A Comparative Grammar of the Dravidian or South-Indian Family of Languages", opines that Malayalam branched from Classical Tamil and over time gained a large amount of Sanskrit vocabulary and lost the personal terminations of verbs.[21] As the language of scholarship and administration, Old-Tamil, which was written in Tamil-Brahmi and the Vatteluttu alphabet later, greatly influenced the early development of Malayalam.
